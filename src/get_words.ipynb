# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
from requests.exceptions import ConnectionError, HTTPError, Timeout

# %%
BASE_URL = "https://corola.racai.ro/lista.html"
def get_soup(url: str = BASE_URL, retries: int = 3, backoff_factor: int = 1) -> BeautifulSoup:
    print(f"Fetching: {url}")
    # response = requests.get(url)
    for attempt in range(retries):
        try:
            # Attempt the request
            response = requests.get(url, timeout=10)  # Add timeout to avoid hanging requests
            response.raise_for_status()  # Raise HTTPError for bad responses (4xx, 5xx)
            soup = BeautifulSoup(response.content, "html.parser")
            # with open("../data/soup.html", "w", encoding="utf-8") as f:
            #     f.write(str(soup))
            return soup
        except (ConnectionError, HTTPError, Timeout) as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            
            # If it's the last attempt, raise the error
            if attempt == retries - 1:
                raise
            
            # Wait before retrying (exponential backoff)
            wait_time = backoff_factor * (2 ** attempt)
            print(f"Retrying in {wait_time} seconds...")
            time.sleep(wait_time)

# %%
soup = get_soup()
# Out:
# Fetching: https://corola.racai.ro/lista.html

# %%
word_list = []
word_type = []
for link in soup.select("a"):
    try:
        base_word = link.select_one("strong").text.strip()
        additional_info = link.text.replace(base_word, "").strip()[1:]
        word_list.append(base_word)
        word_type.append(additional_info)
    except:
        pass

# %%
word_list[:10], word_type[:10]
# Out:
# (['aba',
#   'abac',
#   'abacă',
#   'abacterian',
#   'abager',
#   'abagerie',
#   'abagiu',
#   'abajur',
#   'abandon',
#   'abandona'],
#  ['substantiv',
#   'substantiv',
#   'substantiv',
#   'adjectiv',
#   'substantiv',
#   'substantiv',
#   'substantiv',
#   'substantiv',
#   'substantiv',
#   'verb'])

# %%
# Save the data to csv files
pd.DataFrame({"word": word_list, "type": word_type}).to_csv("../data/romanian_words.csv", index=False)

# %%
df = pd.read_csv("../data/romanian_words.csv")

# %%
def get_syllables(word):
    url = f"https://www.silabe.ro/desparte-in-silabe-{word}.html"
    soup = get_soup(url)
    # with open("../data/soup.html", "w", encoding="utf-8") as f:
    #     f.write(str(soup))
    desp_div = soup.select_one("div.desp")

    if desp_div:
        content = desp_div.text.split('= ')[1].strip()
        words = content.replace("•", "").split()
        formatted_output = "-".join(words)
        return words, formatted_output
    print(f"Failed to fetch: word={word}")
    return [], "not-found"

# %%
syllables = []
joint_syllables = []

for i, row in df.iterrows():
    if i < 5201:
        continue

    syllable_list, joint = get_syllables(row['word'])
    
    syllables.append(syllable_list)
    joint_syllables.append(joint)
    
    i += 1
    if i % 13 == 0:
        time.sleep(3)
    if i % 10 == 0:
        words = list(df.head(i)['word'])[5201:]
        types = list(df.head(i)['type'])[5201:]
        print(len(words), len(types), len(syllables), len(joint_syllables))
        pd.DataFrame({"word": words, "type": types, "syllables" : syllables, "joint_syllables": joint_syllables}).to_csv("../data/temporary_romanian_words5.csv", index=False)
# Out:
# Fetching: https://www.silabe.ro/desparte-in-silabe-artropatie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-artroplastie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-artropod.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-artroscop.html
# Failed to fetch: word=artroscop
# Fetching: https://www.silabe.ro/desparte-in-silabe-artroscopie.html
# Failed to fetch: word=artroscopie
# Fetching: https://www.silabe.ro/desparte-in-silabe-artrotomie.html
# Failed to fetch: word=artrotomie
# Fetching: https://www.silabe.ro/desparte-in-silabe-artroză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-artrozic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-artterapie.html
# Failed to fetch: word=artterapie
# 9 9 9 9
# Fetching: https://www.silabe.ro/desparte-in-silabe-arunca.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aruncare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aruncat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aruncător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aruncător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aruncătură.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvanit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvicol.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvoni.html
# Failed to fetch: word=arvoni
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvonit.html
# Failed to fetch: word=arvonit
# 19 19 19 19
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvună.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvuni.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvunire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arvunit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arz.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arzător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arzător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-arzoi.html
# Failed to fetch: word=arzoi
# Fetching: https://www.silabe.ro/desparte-in-silabe-arzos.html
# Failed to fetch: word=arzos
# Fetching: https://www.silabe.ro/desparte-in-silabe-as.html
# 29 29 29 29
# Fetching: https://www.silabe.ro/desparte-in-silabe-așa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asab.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asalt.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asalta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asaltare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asaltat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asaltat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asaltator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asambla.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asamblaj.html
# 39 39 39 39
# Fetching: https://www.silabe.ro/desparte-in-silabe-asamblare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asamblat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asamblat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asamblor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asană.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asana.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asanare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asanat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asanat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asanator.html
# 49 49 49 49
# Fetching: https://www.silabe.ro/desparte-in-silabe-asanator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așarna.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așarnat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasin.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasină.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasina.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasinare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasinat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asasinat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asbest.html
# Failed to fetch: word=asbest
# 59 59 59 59
# Fetching: https://www.silabe.ro/desparte-in-silabe-ască.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascarid.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascarid.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascaridă.html
# Failed to fetch: word=ascaridă
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascaridioză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascendent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascendent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascendentă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascendență.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensiona.html
# 69 69 69 69
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensional.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensionare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensionat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensionist.html
# Failed to fetch: word=ascensionist
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensiune.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensiv.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensor-clasic.html
# Failed to fetch: word=ascensor-clasic
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascensor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascet.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascetă.html
# 79 79 79 79
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascetic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascetism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascetiza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascetizat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asceză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchia.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchiat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchiere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchietor.html
# 89 89 89 89
# Fetching: https://www.silabe.ro/desparte-in-silabe-aschimodie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchioară.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchios.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așchiuță.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascidie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascită.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascitic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascitic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asclepiad.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asclepiadacee.html
# 99 99 99 99
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascochitoză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascomicetă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascomicete.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascospor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asculta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultătoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultător.html
# 109 109 109 109
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascultător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascunde.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascundere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuns.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuns.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascunzătoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascunzătură.html
# Failed to fetch: word=ascunzătură
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascunziș.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuți.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțime.html
# 119 119 119 119
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțiș.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțitoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțitor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ascuțitunghic.html
# Failed to fetch: word=ascuțitunghic
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseca.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asecare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asedia.html
# 129 129 129 129
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asediu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseismic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseitate.html
# Failed to fetch: word=aseitate
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseleniza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aselenizare.html
# 139 139 139 139
# Fetching: https://www.silabe.ro/desparte-in-silabe-aselenizat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemăluire.html
# Failed to fetch: word=asemăluire
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemăna.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemănare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemănat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemănat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemănător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemănător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemantic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemie.html
# 149 149 149 149
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemui.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemuire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemuit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asemuit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asentiment.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asepsie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseptic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseptiza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseptizare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aseptizat.html
# 159 159 159 159
# Fetching: https://www.silabe.ro/desparte-in-silabe-asert.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aserțiune.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asertiv.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asertoric.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aservi.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aservire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aservit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aservit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aservită.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asesoare.html
# 169 169 169 169
# Fetching: https://www.silabe.ro/desparte-in-silabe-asesor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asexualitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asexuat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așeza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezământ.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezător.html
# Failed to fetch: word=așezător
# Fetching: https://www.silabe.ro/desparte-in-silabe-așezătură.html
# Failed to fetch: word=așezătură
# 179 179 179 179
# Fetching: https://www.silabe.ro/desparte-in-silabe-asezona.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asezonare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asezonat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asezonat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfalt.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfalta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfaltare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfaltat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfaltene.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfaltic.html
# 189 189 189 189
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfaltos.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asferic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfigmie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfinți.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfințire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfințit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfințit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixia.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixiant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixiat.html
# 199 199 199 199
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixiat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixiată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfixiere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfodel.html
# Failed to fetch: word=asfodel
# Fetching: https://www.silabe.ro/desparte-in-silabe-asfodelă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asialie.html
# Failed to fetch: word=asialie
# Fetching: https://www.silabe.ro/desparte-in-silabe-asianic.html
# Failed to fetch: word=asianic
# Fetching: https://www.silabe.ro/desparte-in-silabe-asianism.html
# Failed to fetch: word=asianism
# 209 209 209 209
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiatic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiatic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiatică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiatism.html
# Failed to fetch: word=asiatism
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiduitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiduu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asietă.html
# 219 219 219 219
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigna.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asignare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asignat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asignat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asignație.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigura.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurată.html
# 229 229 229 229
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asigurator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiguratoriu.html
# Failed to fetch: word=asiguratoriu
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimbolie.html
# Failed to fetch: word=asimbolie
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimetric.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimetrie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimila.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilabil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilare.html
# 239 239 239 239
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilație.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilativ.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimilator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimptomatic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimptotă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asimptotic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asin.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asincron.html
# 249 249 249 249
# Fetching: https://www.silabe.ro/desparte-in-silabe-asincronic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asincronism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asindet.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asindetic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asinergie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asintactic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asintaxie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asirian.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiriană.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiriolog.html
# 259 259 259 259
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiriologie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiro-babilonian.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asista.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistant.html
# Failed to fetch: word=asistant
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistentă.html
# 269 269 269 269
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistență.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asistolie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asiză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmațuchi.html
# Failed to fetch: word=asmațuchi
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmățui.html
# Failed to fetch: word=asmățui
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuța.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuțare.html
# Failed to fetch: word=asmuțare
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuți.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuțire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuțit.html
# 279 279 279 279
# Fetching: https://www.silabe.ro/desparte-in-silabe-asmuțit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asocia.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asocial.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociație.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociațional.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociaționism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociaționist.html
# 289 289 289 289
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociativ.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociativitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asociere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asola.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asolament.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asoma.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asomare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asomat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asomatognozie.html
# Failed to fetch: word=asomatognozie
# Fetching: https://www.silabe.ro/desparte-in-silabe-asomator.html
# 299 299 299 299
# Fetching: https://www.silabe.ro/desparte-in-silabe-asonant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asonanță.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asorta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asortabil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asortare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asortat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asortat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asortiment.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asparagină.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asparagus.html
# 309 309 309 309
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspațial.html
# Failed to fetch: word=aspațial
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspect.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspecta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspectat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspectomat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspectual.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspectuos.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspergil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspergiloză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asperitate.html
# 319 319 319 319
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspermie.html
# Failed to fetch: word=aspermie
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspersare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspersiune.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspersor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspidă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspidistră.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspira.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirantă.html
# 329 329 329 329
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirantură.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirație.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirațiune.html
# Failed to fetch: word=aspirațiune
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspirină.html
# 339 339 339 339
# Fetching: https://www.silabe.ro/desparte-in-silabe-asporogen.html
# Failed to fetch: word=asporogen
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspreală.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprete.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprețe.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspri.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprime.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprire.html
# Failed to fetch: word=asprire
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asprit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspriu.html
# 349 349 349 349
# Fetching: https://www.silabe.ro/desparte-in-silabe-aspru.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astâmpăr.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astâmpăra.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astâmpărare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astâmpărat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astatiniu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astazie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asteism.html
# Failed to fetch: word=asteism
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenic.html
# 359 359 359 359
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asteniza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenizare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenopie.html
# Failed to fetch: word=astenopie
# Fetching: https://www.silabe.ro/desparte-in-silabe-astenosferă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aștepta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așteptare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așteptat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așteptat.html
# 369 369 369 369
# Fetching: https://www.silabe.ro/desparte-in-silabe-aster.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astereală.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astereognozie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asteridă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asterie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asterisc.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asterism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așterne.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așternere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-așternut.html
# 379 379 379 379
# Fetching: https://www.silabe.ro/desparte-in-silabe-așternut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asteroid.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asteronim.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astigmat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astigmatic.html
# Failed to fetch: word=astigmatic
# Fetching: https://www.silabe.ro/desparte-in-silabe-astigmatică.html
# Failed to fetch: word=astigmatică
# Fetching: https://www.silabe.ro/desparte-in-silabe-astigmatism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astigmometru.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astm.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astmă.html
# 389 389 389 389
# Fetching: https://www.silabe.ro/desparte-in-silabe-astmatic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astmatiform.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrafobie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astragal.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrahan.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astral.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astralită.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astringent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astringență.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrobiolog.html
# 399 399 399 399
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrobiolog.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrobiologie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astroblast.html
# Failed to fetch: word=astroblast
# Fetching: https://www.silabe.ro/desparte-in-silabe-astroblastom.html
# Failed to fetch: word=astroblastom
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrocit.html
# Failed to fetch: word=astrocit
# Fetching: https://www.silabe.ro/desparte-in-silabe-astroclimat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astroclub.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrodrom.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofizic.html
# 409 409 409 409
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofizică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofizician.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofiziciană.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrofotografie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrogeologie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrograf.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrografie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrolab.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrolatrie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrolog.html
# 419 419 419 419
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrolog.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrologă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrologic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrologie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrometric.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrometrie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrometru.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronaut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronaut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronautic.html
# 429 429 429 429
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronautică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronavă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronim.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronom.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronom.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronomă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronomic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronomicesc.html
# Failed to fetch: word=astronomicesc
# Fetching: https://www.silabe.ro/desparte-in-silabe-astronomie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrospectroscopie.html
# 439 439 439 439
# Fetching: https://www.silabe.ro/desparte-in-silabe-astru.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astruca.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astrucare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupătură.html
# Failed to fetch: word=astupătură
# Fetching: https://www.silabe.ro/desparte-in-silabe-astupuș.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-astuție.html
# 449 449 449 449
# Fetching: https://www.silabe.ro/desparte-in-silabe-astuțios.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asud.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuda.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asudare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asudat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asudeală.html
# Failed to fetch: word=asudeală
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuma.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asumare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asumat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asumat.html
# 459 459 459 459
# Fetching: https://www.silabe.ro/desparte-in-silabe-asumpție.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asumpțiune.html
# Failed to fetch: word=asumpțiune
# Fetching: https://www.silabe.ro/desparte-in-silabe-asupreală.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asupri.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuprire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuprit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuprit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asuprită.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asupritoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asupritor.html
# 469 469 469 469
# Fetching: https://www.silabe.ro/desparte-in-silabe-asupritor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzi.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzitor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-asurzitor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-at.html
# Failed to fetch: word=at
# Fetching: https://www.silabe.ro/desparte-in-silabe-ata.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ață.html
# 479 479 479 479
# Fetching: https://www.silabe.ro/desparte-in-silabe-atac.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataca.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacabil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacantă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacată.html
# 489 489 489 489
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacatoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atacator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataman.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataraxic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataraxic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataraxie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârna.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârnare.html
# 499 499 499 499
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârnat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârnat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârnătoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atârnător.html
# Failed to fetch: word=atârnător
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataș.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașabil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașament.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașamentist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașamentist.html
# 509 509 509 509
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atașată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atât.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațâța.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațâțare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațâțat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațâțător.html
# 519 519 519 519
# Fetching: https://www.silabe.ro/desparte-in-silabe-atavic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atavism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataxic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ataxie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atebrină.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atee.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atehnic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateizare.html
# Failed to fetch: word=ateizare
# 529 529 529 529
# Fetching: https://www.silabe.ro/desparte-in-silabe-atelă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atelaj.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atelectazie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atelie.html
# Failed to fetch: word=atelie
# Fetching: https://www.silabe.ro/desparte-in-silabe-atelier.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atematic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atemporal.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atemporalitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenansă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenanță.html
# Failed to fetch: word=atenanță
# 539 539 539 539
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateneu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenian.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenian.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateniană.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atent.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenta.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentare.html
# Failed to fetch: word=atentare
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentatoare.html
# 549 549 549 549
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenție.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenționa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenționare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenționat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenționat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atențiune.html
# Failed to fetch: word=atențiune
# Fetching: https://www.silabe.ro/desparte-in-silabe-atentiv.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenua.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenuant.html
# 559 559 559 559
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenuare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenuat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenuat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atenuator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterină.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateriza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterizaj.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterizare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterizat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterizat.html
# 569 569 569 569
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterizor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atermal.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterman.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atermic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterogen.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterogeneză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aterom.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateromatoză.html
# Failed to fetch: word=ateromatoză
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateroscleroză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atesta.html
# 579 579 579 579
# Fetching: https://www.silabe.ro/desparte-in-silabe-atestare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atestat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atestat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atetoză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ateu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-athonit.html
# Failed to fetch: word=athonit
# Fetching: https://www.silabe.ro/desparte-in-silabe-athonit.html
# Failed to fetch: word=athonit
# Fetching: https://www.silabe.ro/desparte-in-silabe-atic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aticism.html
# 589 589 589 589
# Fetching: https://www.silabe.ro/desparte-in-silabe-aticist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aticist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atimie.html
# Failed to fetch: word=atimie
# Fetching: https://www.silabe.ro/desparte-in-silabe-aținat.html
# Failed to fetch: word=aținat
# Fetching: https://www.silabe.ro/desparte-in-silabe-aține.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aținere.html
# Failed to fetch: word=aținere
# Fetching: https://www.silabe.ro/desparte-in-silabe-atingător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atinge.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atingere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atins.html
# 599 599 599 599
# Fetching: https://www.silabe.ro/desparte-in-silabe-atins.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aținta.html
# Failed to fetch: word=aținta
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațintat.html
# Failed to fetch: word=ațintat
# Fetching: https://www.silabe.ro/desparte-in-silabe-aținti.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațintire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațintit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațintit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-aținut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațipeală.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațipi.html
# 609 609 609 609
# Fetching: https://www.silabe.ro/desparte-in-silabe-atipic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atipie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațipire.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațipit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațipit.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațișoară.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațița.html
# Failed to fetch: word=ațița
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațițare.html
# Failed to fetch: word=ațițare
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațițat.html
# Failed to fetch: word=ațițat
# Fetching: https://www.silabe.ro/desparte-in-silabe-atitudinal.html
# Failed to fetch: word=atitudinal
# 619 619 619 619
# Fetching: https://www.silabe.ro/desparte-in-silabe-atitudine.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atitudional.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlantic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlantism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlantist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlantist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlantistă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlas.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlaz.html
# 629 629 629 629
# Fetching: https://www.silabe.ro/desparte-in-silabe-atlet.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atletă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atletic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atletism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atmosferă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atmosferic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atmosferiza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atmosferizare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atoatestăpânitoare.html
# Failed to fetch: word=atoatestăpânitoare
# Fetching: https://www.silabe.ro/desparte-in-silabe-atoatestăpânitor.html
# Failed to fetch: word=atoatestăpânitor
# 639 639 639 639
# Fetching: https://www.silabe.ro/desparte-in-silabe-atoatestăpânitor.html
# Failed to fetch: word=atoatestăpânitor
# Fetching: https://www.silabe.ro/desparte-in-silabe-atoateștiutor.html
# Failed to fetch: word=atoateștiutor
# Fetching: https://www.silabe.ro/desparte-in-silabe-atoatevăzător.html
# Failed to fetch: word=atoatevăzător
# Fetching: https://www.silabe.ro/desparte-in-silabe-atol.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atom.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomă.html
# Failed to fetch: word=atomă
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomal.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomar.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomicitate.html
# 649 649 649 649
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomist.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomistic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomistică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomiza.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomizare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomizat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomizator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomizor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atomoelectric.html
# 659 659 659 659
# Fetching: https://www.silabe.ro/desparte-in-silabe-aton.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonal.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonalism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonalitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atonism.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atopic.html
# Failed to fetch: word=atopic
# Fetching: https://www.silabe.ro/desparte-in-silabe-atopie.html
# Failed to fetch: word=atopie
# Fetching: https://www.silabe.ro/desparte-in-silabe-ațos.html
# 669 669 669 669
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotbiruitor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotcunoscătoare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotcunoscător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotcunoscător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotcuprindere.html
# Failed to fetch: word=atotcuprindere
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotcuprinzător.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotînțelegătoare.html
# Failed to fetch: word=atotînțelegătoare
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotînțelegător.html
# Failed to fetch: word=atotînțelegător
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotînțelegător.html
# Failed to fetch: word=atotînțelegător
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotputernic.html
# 679 679 679 679
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotputernic.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotputernică.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-atotputernicie.html
# ...
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloroză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clorură.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clorura.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clorurare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clorurat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clorurie.html
# 9619 9619 9619 9619
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloș.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloșat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloșcă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloșcărie.html
# Failed to fetch: word=cloșcărie
# Fetching: https://www.silabe.ro/desparte-in-silabe-closet.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloț.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloță.html
# Failed to fetch: word=cloță
# Fetching: https://www.silabe.ro/desparte-in-silabe-cloțan.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clou.html
# Failed to fetch: word=clou
# Fetching: https://www.silabe.ro/desparte-in-silabe-clovn.html
# 9629 9629 9629 9629
# Fetching: https://www.silabe.ro/desparte-in-silabe-clovnerie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clovnesc.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clown.html
# Failed to fetch: word=clown
# Fetching: https://www.silabe.ro/desparte-in-silabe-clu.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-club.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clubman.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clucer.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clucereasă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cluj.html
# Failed to fetch: word=cluj
# Fetching: https://www.silabe.ro/desparte-in-silabe-clujean.html
# 9639 9639 9639 9639
# Fetching: https://www.silabe.ro/desparte-in-silabe-clujean.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clujeancă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clupă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clupa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-clupeide.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cneaghină.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cneaz.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cnemidă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cnezat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cnidoblast.html
# 9649 9649 9649 9649
# Fetching: https://www.silabe.ro/desparte-in-silabe-cnocaut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-cnut.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabă.html
# Failed to fetch: word=coabă
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabita.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabitant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabitare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabitat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabitație.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coabitațiune.html
# Failed to fetch: word=coabitațiune
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacă.html
# 9659 9659 9659 9659
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacăz.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacăză.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coace.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacere.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacervat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coachiziție.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacționar.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacționar.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacționară.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacțiune.html
# 9669 9669 9669 9669
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacuzat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coacuzată.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coadă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coadministrator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafa.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafat.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafeză.html
# 9679 9679 9679 9679
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafor.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coafură.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagul.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagula.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulabil.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulabilitate.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulant.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulare.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulat.html
# 9689 9689 9689 9689
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulator.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulogramă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coagulopatie.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coajă.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coală.html
# Fetching: https://www.silabe.ro/desparte-in-silabe-coalescent.html
# Attempt 1 failed: HTTPSConnectionPool(host='www.silabe.ro', port=443): Read timed out. (read timeout=10)
# Retrying in 1 seconds...
# Attempt 2 failed: HTTPSConnectionPool(host='www.silabe.ro', port=443): Max retries exceeded with url: /desparte-in-silabe-coalescent.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x116f1b610>: Failed to resolve 'www.silabe.ro' ([Errno 8] nodename nor servname provided, or not known)"))
# Retrying in 2 seconds...
# Attempt 3 failed: HTTPSConnectionPool(host='www.silabe.ro', port=443): Max retries exceeded with url: /desparte-in-silabe-coalescent.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1274c0910>, 'Connection to www.silabe.ro timed out. (connect timeout=10)'))
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x1274c0910>, 'Connection to www.silabe.ro timed out. (connect timeout=10)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.silabe.ro', port=443): Max retries exceeded with url: /desparte-in-silabe-coalescent.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1274c0910>, 'Connection to www.silabe.ro timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[67], line 8
#       5 if i < 5201:
#       6     continue
# ----> 8 syllable_list, joint = get_syllables(row['word'])
#      10 syllables.append(syllable_list)
#      11 joint_syllables.append(joint)
#
# Cell In[66], line 3, in get_syllables(word)
#       1 def get_syllables(word):
#       2     url = f"https://www.silabe.ro/desparte-in-silabe-{word}.html"
# ----> 3     soup = get_soup(url)
#       4     # with open("../data/soup.html", "w", encoding="utf-8") as f:
#       5     #     f.write(str(soup))
#       6     desp_div = soup.select_one("div.desp")
#
# Cell In[65], line 8, in get_soup(url, retries, backoff_factor)
#       5 for attempt in range(retries):
#       6     try:
#       7         # Attempt the request
# ----> 8         response = requests.get(url, timeout=10)  # Add timeout to avoid hanging requests
#       9         response.raise_for_status()  # Raise HTTPError for bad responses (4xx, 5xx)
#      10         soup = BeautifulSoup(response.content, "html.parser")
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/miniconda3/envs/poem-mode/lib/python3.13/site-packages/requests/adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='www.silabe.ro', port=443): Max retries exceeded with url: /desparte-in-silabe-coalescent.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1274c0910>, 'Connection to www.silabe.ro timed out. (connect timeout=10)'))

# %%
df['syllables'] = syllables
df['syllables_number'] = df['syllables'].apply(lambda x: len(x))

df.to_csv("../data/romanian_words.csv")
